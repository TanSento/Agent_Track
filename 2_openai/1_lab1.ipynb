# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

import os
from dotenv import load_dotenv
from openai import AsyncOpenAI
from agents import Agent, Runner, trace
from agents.models.openai_chatcompletions import OpenAIChatCompletionsModel
from agents import RunConfig

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

# Set up OpenRouter client
openrouter_client = AsyncOpenAI(
    api_key=os.environ["OPENROUTER_API_KEY"],
    base_url="https://openrouter.ai/api/v1",
)

# Choose any OpenRouter-supported model
MODEL = "openai/gpt-4o-mini"

openrouter_model = OpenAIChatCompletionsModel(
    model=MODEL,
    openai_client=openrouter_client,
)

# No model set on the agent — it's injected via RunConfig below
agent = Agent(name="Jokester", instructions="You are a joke teller")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = Runner.run(
        agent,
        "Tell a joke about Autonomous AI Agents",
        run_config=RunConfig(model=openrouter_model),
    )
    print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       3 with trace("Telling a joke"):
#       4     result = Runner.run(
#       5         agent,
#       6         "Tell a joke about Autonomous AI Agents",
#       7         run_config=RunConfig(model=openrouter_model),
#       8     )
# ----> 9     print(result.final_output)
#
# AttributeError: 'coroutine' object has no attribute 'final_output'
# OPENAI_API_KEY is not set, skipping trace export
# OPENAI_API_KEY is not set, skipping trace export

# %%
with trace("Telling a joke"):
    result = await Runner.run(
        agent,
        "Tell a joke about Autonomous AI Agents",
        run_config=RunConfig(model=openrouter_model),
    )
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it couldn't find any common "ground" in their conversations!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
