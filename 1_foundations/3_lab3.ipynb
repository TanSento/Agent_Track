# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr
import os
from datetime import date

# %%
load_dotenv(override=True)

openrouter = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# %%
reader = PdfReader("me/LinkedInProfile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text


reader = PdfReader("me/TanBui_Resume.pdf")
resume = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        resume += text
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 11 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)

# %%
print(linkedin)
# Out:
#
# Contact
# minhtanbuinguyen@gmail.com
# www.linkedin.com/in/tanbui1302
# (LinkedIn)
# Top Skills
# Deep Learning
# Machine Learning
# Computer Vision
# Languages
# English (Full Professional)
# Vietnamese (Native or Bilingual)
# Certifications
# Machine Learning
# Generative AI with Large Language
# Models
# Deep Learning Specialization
# Honors-Awards
# Recognition of Academic
# Achievement - Letter of
# Commendation
# Tan Bui
# Machine Learning Enthusiast
# Greater Perth Area
# Summary
# At Neorise, I worked on an exciting project to develop an emotion
# classifier. We used advanced technologies like Wave2Vec and
# a Large Language Model pipeline to create a system that could
# understand and respond to users' emotions, making their experience
# more intuitive. My background in Python and Machine Learning,
# which I developed while working as a Teaching Assistant at Curtin
# University, was crucial for this project. We successfully combined
# ...

# %%
print(resume)
# Out:
#    Mob : +61 424 473 234  Email : minhtanbuinguyen@gmail.com  LinkedIn : www.linkedin.com/in/tanbui1302/  GitHub : https://github.com/TanSento  PROFILE A Master of Predictive Analytics and Mechanical Engineering (Honours) graduate from Curtin University with hands-on experience in data analysis, predictive modelling, and building full-stack analytics applications. Skilled in transforming complex datasets into actionable business insights through dashboards, forecasting models, and automated reporting pipelines. Seeking a software engineering role where I can apply my full-stack and AI development experience to build practical LLM-powered applications and multi-agent systems for real-world business problems. Experienced in working with cross-functional teams across research, conservation, and startup environments, with strong communication skills developed through three years of academic tutoring.   TECHNICAL SKILLS • Analytics & Modelling: Predictive modelling, regression analysis, t
# ...

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Tan Bui"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
Today's date is {date.today().strftime('%B %d, %Y')}. Use this to accurately determine {name}'s current role and tenure in any positions. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n## Resume:\n{resume}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Tan Bui. You are answering questions on Tan Bui's website, particularly questions related to Tan Bui's career, background, skills and experience. Your responsibility is to represent Tan Bui for interactions on the website as faithfully as possible. You are given a summary of Tan Bui's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. Today's date is April 19, 2026. Use this to accurately determine Tan Bui's current role and tenure in any positions. If you don't know the answer, say so.\n\n## Summary:\nMy name is Tan Bui. I'm an AI enthusiast, software engineer and data scientist. I'm originally from Vietnam but I now live and work in Perth, Western Australia.\nBeside working with AI tools, I also love going to gym for resistance training and playing video games. I've always enjoyed any discussions related to strength training or gam
# ...

# %%
def chat(message, history):   # history is automatically provided by Gradio's ChatInterface
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openrouter.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %% [markdown]
# <div style="font-size: 0.85em;">
#
# #### How `Evaluation(BaseModel)` works in this notebook
#
# The class defines the **contract** for what the evaluator LLM must return:
#
# ```python
# class Evaluation(BaseModel):
#     is_acceptable: bool   # Did the agent answer well? True/False
#     feedback: str         # Why? Human-readable reason
# ```
#
# It plugs into **3 places** in the quality-control pipeline:
#
# ---
#
# **1. Sent to the LLM as a schema constraint**
# ```python
# response_format={
#     "type": "json_schema",
#     "json_schema": {
#         "name": "Evaluation",
#         "schema": Evaluation.model_json_schema()  # <- auto-generated from the class
#     }
# }
# ```
# `model_json_schema()` converts your class into a JSON Schema and **tells the LLM exactly what shape to output**.
#
# ---
#
# **2. Parsed back into the typed object**
# ```python
# return Evaluation(**json.loads(response.choices[0].message.content))
# ```
# The raw JSON string from the LLM is validated back into the `Evaluation` object - so `is_acceptable` is a real `bool`, not the string `"true"`.
#
# ---
#
# **3. Drives the rerun logic**
# ```python
# evaluation = evaluate(reply, message, history)
#
# if evaluation.is_acceptable:            # safe bool check
#     return reply                        # Pass through
# else:
#     reply = rerun(..., evaluation.feedback)  # Retry with feedback injected
# ```
#
# ---
#
# **Full flow**
# ```
# User message
#      |
#      v
# Agent (gpt-4o-mini) -> reply (string)
#      |
#      v
# evaluate(reply, message, history)
#      |
#      v
# Evaluator LLM (gemini-2.5-flash)
#      -> constrained by Evaluation.model_json_schema()
#      -> returns JSON: {"is_acceptable": true, "feedback": "..."}
#      |
#      v
# Evaluation(**json.loads(...))   <- Pydantic validates + types
#      |
#      v
# evaluation.is_acceptable -> True  -> return reply (PASS)
#                          -> False -> rerun with evaluation.feedback (RETRY)
# ```
#
# > **Key insight**: The class is the glue between the LLM's raw text output and your Python logic -
# > it tells the LLM what to produce, validates what comes back, and gives you safe `.attribute` access.
#
# </div>

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n## Resume:\n{resume}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
# import os
# gemini = OpenAI(
#     api_key=os.getenv("GOOGLE_API_KEY"), 
#     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
# )

# %%
# def evaluate(reply, message, history) -> Evaluation:

#     messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
#     response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
#     return response.choices[0].message.parsed


import json

def evaluate(reply, message, history) -> Evaluation:
    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = openrouter.chat.completions.create(
        model="google/gemini-2.5-flash",
        messages=messages,
        response_format={
            "type": "json_schema",
            "json_schema": {
                "name": "Evaluation",
                "schema": Evaluation.model_json_schema()
            }
        }
    )
    return Evaluation(**json.loads(response.choices[0].message.content))

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openrouter.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "As of now, I do not hold any patents. My focus has primarily been on developing and implementing machine learning projects and applications in areas such as emotion classification and wildlife protection. However, I am always exploring innovative ideas in AI and software development, so it's possible that I may pursue patent opportunities in the future. If you have any specific questions about my work or interests, feel free to ask!"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent directly answers the question and provides additional context, staying within character and professional tone.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openrouter.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):   ## To trigger the evaluator to ask for a rerun if the response is in pig latin
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openrouter.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Passed evaluation - returning reply
